# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\temp\Corizo\1613615-Stock_Price_data_set.csv")

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\temp\Corizo\1613615-Stock_Price_data_set.csv", header=0, index_col='Date', parse_dates=True)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...                ...         ...         ...         ...         ...
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# ...

# %%
df.shape
# Out:
# (1009, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1009 entries, 2018-02-05 to 2022-02-04
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1009 non-null   float64
#  1   High       1009 non-null   float64
#  2   Low        1009 non-null   float64
#  3   Close      1009 non-null   float64
#  4   Adj Close  1009 non-null   float64
#  5   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 55.2 KB

# %%
df.isna().any()
# Out:
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %%
df.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...                ...         ...         ...         ...         ...
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# ...

# %%
import datetime

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...                ...         ...         ...         ...         ...
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# ...

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.index
# Out:
# DatetimeIndex(['2018-02-05', '2018-02-06', '2018-02-07', '2018-02-08',
#                '2018-02-09', '2018-02-12', '2018-02-13', '2018-02-14',
#                '2018-02-15', '2018-02-16',
#                ...
#                '2022-01-24', '2022-01-25', '2022-01-26', '2022-01-27',
#                '2022-01-28', '2022-01-31', '2022-02-01', '2022-02-02',
#                '2022-02-03', '2022-02-04'],
#               dtype='datetime64[ns]', name='Date', length=1009, freq=None)

# %% [markdown]
# # Overall Trends

# %%
plt.plot(df.index , df['Open'])
plt.xticks(rotation=90)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.grid(True)
plt.show()

# %%
plt.plot(df.index , df['Adj Close'])
plt.xticks(rotation=90)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.grid(True)
plt.show()

# %%
plt.plot(df.index , df['Volume'])
plt.xticks(rotation=90)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.grid(True)
plt.show()

# %% [markdown]
# # Annual Analysis

# %%
df_18 = df[pd.Timestamp('2018-01-01'):pd.Timestamp('2018-12-31')]
df_19 = df[pd.Timestamp('2019-01-01'):pd.Timestamp('2019-12-31')]
df_20 = df[pd.Timestamp('2020-01-01'):pd.Timestamp('2020-12-31')]
df_21 = df[pd.Timestamp('2021-01-01'):pd.Timestamp('2021-12-31')]
df_22 = df[pd.Timestamp('2022-01-01'):pd.Timestamp('2022-12-31')]

# %%
df_18
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...                ...         ...         ...         ...         ...
# 2018-12-24  242.000000  250.649994  233.679993  233.880005  233.880005
# 2018-12-26  233.919998  254.500000  231.229996  253.669998  253.669998
# 2018-12-27  250.110001  255.589996  240.100006  255.570007  255.570007
# 2018-12-28  257.940002  261.910004  249.800003  256.079987  256.079987
# 2018-12-31  260.160004  270.100006  260.000000  267.660004  267.660004
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# ...

# %%
plt.plot(df_18.index, df_18['Open'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
plt.plot(df_18.index, df_18['Adj Close'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
plt.plot(df_18.index, df_18['Volume'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
df_19
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-02  259.279999  269.750000  256.579987  267.660004  267.660004
# 2019-01-03  270.200012  275.790009  264.429993  271.200012  271.200012
# 2019-01-04  281.880005  297.799988  278.540009  297.570007  297.570007
# 2019-01-07  302.100006  316.799988  301.649994  315.339996  315.339996
# 2019-01-08  319.980011  320.589996  308.010010  320.269989  320.269989
# ...                ...         ...         ...         ...         ...
# 2019-12-24  334.010010  335.700012  331.600006  333.200012  333.200012
# 2019-12-26  334.600006  336.459991  332.010010  332.630005  332.630005
# 2019-12-27  332.959991  333.820007  326.010010  329.089996  329.089996
# 2019-12-30  329.079987  329.190002  322.859985  323.309998  323.309998
# 2019-12-31  322.000000  324.920013  321.089996  323.570007  323.570007
#
#               Volume
# Date
# 2019-01-02  11679500
# 2019-01-03  14969600
# 2019-01-04  19330100
# ...

# %%
plt.plot(df_19.index, df_19['Open'])
plt.grid(True)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=90)
plt.show()

# %%
plt.plot(
# 2022-01-13  537.059998  540.789978  518.260010  519.200012  519.200012
# 2022-01-14  517.599976  538.369995  511.880005  525.690002  525.690002
# 2022-01-18  520.080017  521.750000  508.679993  510.799988  510.799988
# 2022-01-19  515.000000  523.210022  510.510010  515.859985  515.859985
# ...

# %% [markdown]
# # Open and Close Price Difference

# %%
df['diff'] = df['Open'] - df['Close']
df_diff = df.resample('W').mean()
df_diff.tail(10)

df_18_diff = df[pd.Timestamp('2018-01-01'):pd.Timestamp('2018-12-31')]
df_19_diff = df[pd.Timestamp('2019-01-01'):pd.Timestamp('2019-12-31')]
df_20_diff = df[pd.Timestamp('2020-01-01'):pd.Timestamp('2020-12-31')]
df_21_diff = df[pd.Timestamp('2021-01-01'):pd.Timestamp('2021-12-31')]
df_22_diff = df[pd.Timestamp('2022-01-01'):pd.Timestamp('2022-12-31')]

# %%
f, ax = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)

ax[0,0].scatter(df_diff.loc['2018-01-01':'2018-12-31'].index, df_diff.loc['2018-01-01':'2018-12-31']['diff']
, color='r')
ax[0,0].grid(True)
ax[0,0].tick_params(labelrotation=90)
ax[0,0].set_title('2018');

ax[0,1].scatter(df_diff.loc['2019-01-01':'2019-12-31'].index, df_diff.loc['2019-01-01':'2019-12-31']['diff']
, color='r')
ax[0,1].grid(True)
ax[0,1].tick_params(labelrotation=90)
ax[0,1].set_title('2019');

ax[1,0].scatter(df_diff.loc['2020-01-01':'2020-12-31'].index, df_diff.loc['2020-01-01':'2020-12-31']['diff']
, color='r')
ax[1,0].grid(True)
ax[1,0].tick_params(labelrotation=90)
ax[1,0].set_title('2020');

ax[1,1].scatter(df_diff.loc['2021-01-01':'2021-12-31'].index, df_diff.loc['2021-01-01':'2021-12-31']['diff']
, color='r')
ax[1,1].grid(True)
ax[1,1].tick_params(labelrotation=90)
ax[1,1].set_title('2021');

# %% [markdown]
# # Daily Returns (Moving Windows)

# %%
daily_close_df = df[['Adj Close']]

# Daily returns
daily_pct_change_df = daily_close_df.pct_change()

daily_pct_change_df.fillna(0, inplace=True)

daily_pct_change_df.head()
# Out:
#             Adj Close
# Date
# 2018-02-05   0.000000
# 2018-02-06   0.045072
# 2018-02-07  -0.004366
# 2018-02-08  -0.054657
# 2018-02-09  -0.002519

# %%
daily_pct_change_df.hist(bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'Adj Close'}>]], dtype=object)

# %%
import seaborn as sns
sns.set()

# %%
f, axes = plt.subplots(figsize=(12, 7))

sns.distplot(daily_pct_change_df['Adj Close'], color="b");
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Volatility

# %% [markdown]
# import numpy as np
#
# min_periods = 75
#
# vol = daily_pct_change_df.rolling(min_periods).std() * np.sqrt(min_periods)
#
# vol.fillna(0,inplace=True)
#
# vol.tail()

# %%
vol.plot(figsize=(10, 8))
plt.show()

# %% [markdown]
# # Rolling Means

# %%
df_adj_close_px = df['Adj Close']
# Short moving window rolling mean
df['42'] = df_adj_close_px.rolling(window=40).mean()

# Long moving window rolling mean
df['252'] = df_adj_close_px.rolling(window=252).mean()

df[['Adj Close', '42', '252']].plot(title="Rolling Means")
plt.show()
